# %% [markdown]
# <a href="https://colab.research.google.com/github/dauphin95/data_spring/blob/master/1_basic_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
# !ls -l
# Out:
# total 8
# drwx------ 5 root root 4096 Oct 14 05:27 drive
# drwxr-xr-x 1 root root 4096 Oct  8 13:45 sample_data

# %%
# !cp ./drive/MyDrive/training_data.zip .

# %%
# !unzip training_data.zip

# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img

# %%
IMG_DIM = (150, 150)

train_files = glob.glob('training_data/*')
train_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in train_files]
train_imgs = np.array(train_imgs)
train_labels = [fn.split('/')[1].split('.')[0].strip() for fn in train_files]

validation_files = glob.glob('validation_data/*')
validation_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in validation_files]
validation_imgs = np.array(validation_imgs)
validation_labels = [fn.split('/')[1].split('.')[0].strip() for fn in validation_files]

print('Train dataset shape:', train_imgs.shape, 
      '\tValidation dataset shape:', validation_imgs.shape)
# Out:
# Train dataset shape: (3000, 150, 150, 3) 	Validation dataset shape: (1000, 150, 150, 3)

# %%
train_imgs_scaled = train_imgs.astype('float32')
validation_imgs_scaled  = validation_imgs.astype('float32')
train_imgs_scaled /= 255
validation_imgs_scaled /= 255

# %%
print(train_imgs[99].shape)
array_to_img(train_imgs[99])
# Out:
# (150, 150, 3)
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F2DF87ED210>

# %%
batch_size = 50
num_classes = 2
epochs = 100
input_shape = (150, 150, 3)

# encode text category labels
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(train_labels)
train_labels_enc = le.transform(train_labels)
validation_labels_enc = le.transform(validation_labels)

print(train_labels[1495:1505], train_labels_enc[1495:1505])
# Out:
# ['dog', 'dog', 'dog', 'cat', 'cat', 'dog', 'dog', 'cat', 'dog', 'cat'] [1 1 1 0 0 1 1 0 1 0]

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers

# %% [markdown]
# ### Model Case I

# %%
model = Sequential()

model.add(Conv2D(16, kernel_size=(3, 3), activation='relu', padding="same",
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        9280
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               21234176
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 21,318,273
# Trainable params: 21,318,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer= 'ADAM', # optimizers.RMSprop(lr=0.0001)
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        9280
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               21234176
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 21,318,273
# Trainable params: 21,318,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x=train_imgs_scaled, y=train_labels_enc,
                    validation_data=(validation_imgs_scaled, validation_labels_enc),
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1)
# Out:
# Epoch 1/100
# 60/60 [==============================] - 36s 93ms/step - loss: 0.7949 - accuracy: 0.5253 - val_loss: 0.6699 - val_accuracy: 0.5840
# Epoch 2/100
# 60/60 [==============================] - 5s 85ms/step - loss: 0.6290 - accuracy: 0.6507 - val_loss: 0.6228 - val_accuracy: 0.6300
# Epoch 3/100
# 60/60 [==============================] - 5s 86ms/step - loss: 0.5722 - accuracy: 0.6943 - val_loss: 0.5991 - val_accuracy: 0.6910
# Epoch 4/100
# 60/60 [==============================] - 5s 86ms/step - loss: 0.5033 - accuracy: 0.7480 - val_loss: 0.5768 - val_accuracy: 0.7200
# Epoch 5/100
# 60/60 [==============================] - 5s 86ms/step - loss: 0.4333 - accuracy: 0.7860 - val_loss: 0.6040 - val_accuracy: 0.7040
# Epoch 6/100
# 60/60 [==============================] - 5s 87ms/step - loss: 0.3671 - accuracy: 0.8350 - val_loss: 0.6133 - val_accuracy: 0.7050
# Epoch 7/100
# 60/60 [==============================] - 5s 82ms/step - loss: 0.2883 - accuracy: 0.8690 - val_loss: 0.6928 - val_accuracy: 0.7290
# Epoch 8/100
# 60/60 [==============================] - 5s 86ms/step - loss: 0.2120 - accuracy: 0.9117 - val_loss: 0.9337 - val_accuracy: 0.6960
# Epoch 9/100
# 60/60 [==============================] - 5s 83ms/step - loss: 0.1479 - accuracy: 0.9390 - val_loss: 1.0772 - val_accuracy: 0.7070
# Epoch 10/100
# 60/60 [==============================] - 5s 86ms/step - loss: 0.0993 - accuracy: 0.9627 - val_loss: 1.0698 - val_accuracy: 0.7160
# Epoch 11/100
# 60/60 [==============================] - 5s 85ms/step - loss: 0.0805 - accuracy: 0.9723 - val_loss: 1.3915 - val_accuracy: 0.7080
# Epoch 12/100
# 60/60 [==============================] - 5s 86ms/step - loss: 0.0479 - accuracy: 0.9853 - val_loss: 1.5754 - val_accuracy: 0.7110
# Epoch 13/100
# 60/60 [==============================] - 5s 87ms/step - loss: 0.0231 - accuracy: 0.9943 - val_loss: 1.6731 - val_accuracy: 0.7140
# Epoch 14/100
# 60/60 [==============================] - 5s 82ms/step - loss: 0.0183 - accuracy: 0.9963 - val_loss: 1.8791 - val_accuracy: 0.7080
# Epoch 15/100
# 60/60 [==============================] - 5s 86ms/step - loss: 0.0593 - accuracy: 0.9803 - val_loss: 1.8334 - val_accuracy: 0.6670
# Epoch 16/100
# 60/60 [==============================] - 5s 83ms/step - loss: 0.0539 - accuracy: 0.9820 - val_loss: 1.6339 - val_accuracy: 0.6960
# Epoch 17/100
# 60/60 [==============================] - 5s 82ms/step - loss: 0.0193 - accuracy: 0.9943 - val_loss: 1.9869 - val_accuracy: 0.6810
# Epoch 18/100
# 60/60 [==============================] - 5s 87ms/step - loss: 0.0197 - accuracy: 0.9943 - val_loss: 1.7807 - val_accuracy: 0.6990
# Epoch 19/100
# 60/60 [==============================] - 5s 86ms/step - loss: 0.0074 - accuracy: 0.9990 - val_loss: 2.0949 - val_accuracy: 0.7100
# Epoch 20/100
# 60/60 [==============================] - 5s 83ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.3252 - val_accuracy: 0.7210
# Epoch 21/100
# 60/60 [==============================] - 5s 83ms/step - loss: 8.4475e-04 - accuracy: 1.0000 - val_loss: 2.4180 - val_accuracy: 0.7180
# Epoch 22/100
# 60/60 [==============================] - 5s 83ms/step - loss: 5.2855e-04 - accuracy: 1.0000 - val_loss: 2.4867 - val_accuracy: 0.7150
# Epoch 23/100
# 60/60 [==============================] - 5s 83ms/step - loss: 3.9624e-04 - accuracy: 1.0000 - val_loss: 2.5317 - val_accuracy: 0.7150
# Epoch 24/100
# 60/60 [==============================] - 5s 83ms/step - loss: 3.1903e-04 - accuracy: 1.0000 - val_loss: 2.5802 - val_accuracy: 0.7150
# Epoch 25/100
# 60/60 [==============================] - 5s 86ms/step - loss: 2.6487e-04 - accuracy: 1.0000 - val_loss: 2.6139 - val_accuracy: 0.7130
# Epoch 26/100
# 60/60 [==============================] - 5s 85ms/step - loss: 2.2362e-04 - accuracy: 1.0000 - val_loss: 2.6569 - val_accuracy: 0.7140
# Epoch 27/100
# 60/60 [==============================] - 5s 86ms/step - loss: 1.9349e-04 - accuracy: 1.0000 - val_loss: 2.6969 - val_accuracy: 0.7180
# Epoch 28/100
# 60/60 [==============================] - 5s 86ms/step - loss: 1.6502e-04 - accuracy: 1.0000 - val_loss: 2.7158 - val_accuracy: 0.7190
# Epoch 29/100
# 60/60 [==============================] - 5s 86ms/step - loss: 1.4379e-04 - accuracy: 1.0000 - val_loss: 2.7435 - val_accuracy: 0.7160
# Epoch 30/100
# 60/60 [==============================] - 5s 85ms/step - loss: 1.2579e-04 - accuracy: 1.0000 - val_loss: 2.7811 - val_accuracy: 0.7170
# Epoch 31/100
# 60/60 [==============================] - 5s 85ms/step - loss: 1.1261e-04 - accuracy: 1.0000 - val_loss: 2.8005 - val_accuracy: 0.7170
# Epoch 32/100
# 60/60 [==============================] - 5s 85ms/step - loss: 9.7867e-05 - accuracy: 1.0000 - val_loss: 2.8213 - val_accuracy: 0.7170
# Epoch 33/100
# 60/60 [==============================] - 5s 84ms/step - loss: 8.4802e-05 - accuracy: 1.0000 - val_loss: 2.8410 - val_accuracy: 0.7150
# Epoch 34/100
# 60/60 [==============================] - 5s 83ms/step - loss: 7.3941e-05 - accuracy: 1.0000 - val_loss: 2.8596 - val_accuracy: 0.7180
# Epoch 35/100
# 60/60 [==============================] - 5s 82ms/step - loss: 6.4669e-05 - accuracy: 1.0000 - val_loss: 2.8733 - val_accuracy: 0.7150
# Epoch 36/100
# 60/60 [==============================] - 5s 86ms/step - loss: 5.7023e-05 - accuracy: 1.0000 - val_loss: 2.8943 - val_accuracy: 0.7150
# Epoch 37/100
# 60/60 [==============================] - 5s 86ms/step - loss: 4.9838e-05 - accuracy: 1.0000 - val_loss: 2.9083 - val_accuracy: 0.7150
# Epoch 38/100
# 60/60 [==============================] - 5s 86ms/step - loss: 4.3825e-05 - accuracy: 1.0000 - val_loss: 2.9247 - val_accuracy: 0.7160
# Epoch 39/100
# 60/60 [==============================] - 5s 83ms/step - loss: 3.9213e-05 - accuracy: 1.0000 - val_loss: 2.9384 - val_accuracy: 0.7170
# Epoch 40/100
# 60/60 [==============================] - 5s 83ms/step - loss: 3.4765e-05 - accuracy: 1.0000 - val_loss: 2.9484 - val_accuracy: 0.7180
# Epoch 41/100
# 60/60 [==============================] - 5s 86ms/step - loss: 3.0722e-05 - accuracy: 1.0000 - val_loss: 2.9625 - val_accuracy: 0.7180
# Epoch 42/100
# 60/60 [==============================] - 5s 85ms/step - loss: 2.7359e-05 - accuracy: 1.0000 - val_loss: 2.9773 - val_accuracy: 0.7180
# Epoch 43/100
# 60/60 [==============================] - 5s 86ms/step - loss: 2.4559e-05 - accuracy: 1.0000 - val_loss: 2.9811 - val_accuracy: 0.7200
# Epoch 44/100
# 60/60 [==============================] - 5s 86ms/step - loss: 2.1913e-05 - accuracy: 1.0000 - val_loss: 2.9946 - val_accuracy: 0.7200
# Epoch 45/100
# 60/60 [==============================] - 5s 82ms/step - loss: 1.9566e-05 - accuracy: 1.0000 - val_loss: 3.0011 - val_accuracy: 0.7200
# Epoch 46/100
# 60/60 [==============================] - 5s 82ms/step - loss: 1.7262e-05 - accuracy: 1.0000 - val_loss: 3.0133 - val_accuracy: 0.7200
# Epoch 47/100
# 60/60 [==============================] - 5s 86ms/step - loss: 1.5427e-05 - accuracy: 1.0000 - val_loss: 3.0286 - val_accuracy: 0.7170
# Epoch 48/100
# 60/60 [==============================] - 5s 82ms/step - loss: 1.3854e-05 - accuracy: 1.0000 - val_loss: 3.0332 - val_accuracy: 0.7190
# Epoch 49/100
# 60/60 [==============================] - 5s 86ms/step - loss: 1.2333e-05 - accuracy: 1.0000 - val_loss: 3.0413 - val_accuracy: 0.7190
# Epoch 50/100
# 60/60 [==============================] - 5s 82ms/step - loss: 1.1238e-05 - accuracy: 1.0000 - val_loss: 3.0578 - val_accuracy: 0.7220
# Epoch 51/100
# 60/60 [==============================] - 5s 86ms/step - loss: 9.9561e-06 - accuracy: 1.0000 - val_loss: 3.0568 - val_accuracy: 0.7180
# Epoch 52/100
# 60/60 [==============================] - 5s 83ms/step - loss: 9.0674e-06 - accuracy: 1.0000 - val_loss: 3.0729 - val_accuracy: 0.7220
# Epoch 53/100
# 60/60 [==============================] - 5s 86ms/step - loss: 8.1928e-06 - accuracy: 1.0000 - val_loss: 3.0800 - val_accuracy: 0.7200
# Epoch 54/100
# 60/60 [==============================] - 5s 83ms/step - loss: 7.4637e-06 - accuracy: 1.0000 - val_loss: 3.0872 - val_accuracy: 0.7170
# Epoch 55/100
# 60/60 [==============================] - 5s 87ms/step - loss: 6.8324e-06 - accuracy: 1.0000 - val_loss: 3.1047 - val_accuracy: 0.7200
# Epoch 56/100
# 60/60 [==============================] - 5s 86ms/step - loss: 6.1538e-06 - accuracy: 1.0000 - val_loss: 3.1121 - val_accuracy: 0.7190
# Epoch 57/100
# 60/60 [==============================] - 5s 83ms/step - loss: 5.6320e-06 - accuracy: 1.0000 - val_loss: 3.1298 - val_accuracy: 0.7180
# Epoch 58/100
# 60/60 [==============================] - 5s 86ms/step - loss: 5.1908e-06 - accuracy: 1.0000 - val_loss: 3.1312 - val_accuracy: 0.7190
# Epoch 59/100
# 60/60 [==============================] - 5s 84ms/step - loss: 4.7504e-06 - accuracy: 1.0000 - val_loss: 3.1396 - val_accuracy: 0.7200
# Epoch 60/100
# 60/60 [==============================] - 5s 83ms/step - loss: 4.3715e-06 - accuracy: 1.0000 - val_loss: 3.1512 - val_accuracy: 0.7170
# Epoch 61/100
# 60/60 [==============================] - 5s 86ms/step - loss: 4.0656e-06 - accuracy: 1.0000 - val_loss: 3.1639 - val_accuracy: 0.7170
# Epoch 62/100
# 60/60 [==============================] - 5s 86ms/step - loss: 3.8053e-06 - accuracy: 1.0000 - val_loss: 3.1711 - val_accuracy: 0.7160
# Epoch 63/100
# 60/60 [==============================] - 5s 86ms/step - loss: 3.5057e-06 - accuracy: 1.0000 - val_loss: 3.1767 - val_accuracy: 0.7180
# Epoch 64/100
# 60/60 [==============================] - 5s 83ms/step - loss: 3.2614e-06 - accuracy: 1.0000 - val_loss: 3.1806 - val_accuracy: 0.7200
# Epoch 65/100
# 60/60 [==============================] - 5s 85ms/step - loss: 3.0462e-06 - accuracy: 1.0000 - val_loss: 3.1911 - val_accuracy: 0.7190
# Epoch 66/100
# 60/60 [==============================] - 5s 86ms/step - loss: 2.8544e-06 - accuracy: 1.0000 - val_loss: 3.1991 - val_accuracy: 0.7180
# Epoch 67/100
# 60/60 [==============================] - 5s 86ms/step - loss: 2.6919e-06 - accuracy: 1.0000 - val_loss: 3.2065 - val_accuracy: 0.7180
# Epoch 68/100
# 60/60 [==============================] - 5s 82ms/step - loss: 2.5017e-06 - accuracy: 1.0000 - val_loss: 3.2165 - val_accuracy: 0.7170
# Epoch 69/100
# 60/60 [==============================] - 5s 82ms/step - loss: 2.3377e-06 - accuracy: 1.0000 - val_loss: 3.2225 - val_accuracy: 0.7210
# Epoch 70/100
# 60/60 [==============================] - 5s 87ms/step - loss: 2.2094e-06 - accuracy: 1.0000 - val_loss: 3.2327 - val_accuracy: 0.7200
# Epoch 71/100
# 60/60 [==============================] - 5s 85ms/step - loss: 2.0670e-06 - accuracy: 1.0000 - val_loss: 3.2406 - val_accuracy: 0.7210
# Epoch 72/100
# 60/60 [==============================] - 5s 86ms/step - loss: 1.9458e-06 - accuracy: 1.0000 - val_loss: 3.2469 - val_accuracy: 0.7230
# Epoch 73/100
# 60/60 [==============================] - 5s 86ms/step - loss: 1.8476e-06 - accuracy: 1.0000 - val_loss: 3.2549 - val_accuracy: 0.7230
# Epoch 74/100
# 60/60 [==============================] - 5s 84ms/step - loss: 1.7355e-06 - accuracy: 1.0000 - val_loss: 3.2641 - val_accuracy: 0.7220
# Epoch 75/100
# 60/60 [==============================] - 5s 83ms/step - loss: 1.6598e-06 - accuracy: 1.0000 - val_loss: 3.2714 - val_accuracy: 0.7220
# Epoch 76/100
# 60/60 [==============================] - 5s 87ms/step - loss: 1.5632e-06 - accuracy: 1.0000 - val_loss: 3.2771 - val_accuracy: 0.7230
# Epoch 77/100
# 60/60 [==============================] - 5s 84ms/step - loss: 1.4782e-06 - accuracy: 1.0000 - val_loss: 3.2815 - val_accuracy: 0.7230
# Epoch 78/100
# 60/60 [==============================] - 5s 86ms/step - loss: 1.4054e-06 - accuracy: 1.0000 - val_loss: 3.2938 - val_accuracy: 0.7230
# Epoch 79/100
# 60/60 [==============================] - 5s 86ms/step - loss: 1.3258e-06 - accuracy: 1.0000 - val_loss: 3.3012 - val_accuracy: 0.7230
# Epoch 80/100
# 60/60 [==============================] - 5s 87ms/step - loss: 1.2680e-06 - accuracy: 1.0000 - val_loss: 3.3076 - val_accuracy: 0.7230
# Epoch 81/100
# 60/60 [==============================] - 5s 86ms/step - loss: 1.2039e-06 - accuracy: 1.0000 - val_loss: 3.3144 - val_accuracy: 0.7230
# Epoch 82/100
# 60/60 [==============================] - 5s 86ms/step - loss: 1.1429e-06 - accuracy: 1.0000 - val_loss: 3.3198 - val_accuracy: 0.7220
# Epoch 83/100
# 60/60 [==============================] - 5s 87ms/step - loss: 1.0875e-06 - accuracy: 1.0000 - val_loss: 3.3255 - val_accuracy: 0.7230
# Epoch 84/100
# 60/60 [==============================] - 5s 83ms/step - loss: 1.0341e-06 - accuracy: 1.0000 - val_loss: 3.3347 - val_accuracy: 0.7220
# Epoch 85/100
# 60/60 [==============================] - 5s 86ms/step - loss: 9.8192e-07 - accuracy: 1.0000 - val_loss: 3.3364 - val_accuracy: 0.7220
# Epoch 86/100
# 60/60 [==============================] - 5s 86ms/step - loss: 9.4435e-07 - accuracy: 1.0000 - val_loss: 3.3455 - val_accuracy: 0.7220
# Epoch 87/100
# 60/60 [==============================] - 5s 86ms/step - loss: 8.9827e-07 - accuracy: 1.0000 - val_loss: 3.3526 - val_accuracy: 0.7230
# Epoch 88/100
# 60/60 [==============================] - 5s 84ms/step - loss: 8.6000e-07 - accuracy: 1.0000 - val_loss: 3.3587 - val_accuracy: 0.7230
# Epoch 89/100
# 60/60 [==============================] - 5s 83ms/step - loss: 8.1827e-07 - accuracy: 1.0000 - val_loss: 3.3642 - val_accuracy: 0.7230
# Epoch 90/100
# 60/60 [==============================] - 5s 87ms/step - loss: 7.8810e-07 - accuracy: 1.0000 - val_loss: 3.3693 - val_accuracy: 0.7230
# Epoch 91/100
# 60/60 [==============================] - 5s 83ms/step - loss: 7.5175e-07 - accuracy: 1.0000 - val_loss: 3.3767 - val_accuracy: 0.7220
# Epoch 92/100
# 60/60 [==============================] - 5s 87ms/step - loss: 7.1924e-07 - accuracy: 1.0000 - val_loss: 3.3856 - val_accuracy: 0.7190
# Epoch 93/100
# 60/60 [==============================] - 5s 83ms/step - loss: 6.8548e-07 - accuracy: 1.0000 - val_loss: 3.3894 - val_accuracy: 0.7210
# Epoch 94/100
# 60/60 [==============================] - 5s 84ms/step - loss: 6.5963e-07 - accuracy: 1.0000 - val_loss: 3.3964 - val_accuracy: 0.7210
# Epoch 95/100
# 60/60 [==============================] - 5s 86ms/step - loss: 6.3528e-07 - accuracy: 1.0000 - val_loss: 3.4038 - val_accuracy: 0.7190
# Epoch 96/100
# 60/60 [==============================] - 5s 83ms/step - loss: 6.0518e-07 - accuracy: 1.0000 - val_loss: 3.4083 - val_accuracy: 0.7210
# Epoch 97/100
# 60/60 [==============================] - 5s 83ms/step - loss: 5.8132e-07 - accuracy: 1.0000 - val_loss: 3.4141 - val_accuracy: 0.7190
# Epoch 98/100
# 60/60 [==============================] - 5s 87ms/step - loss: 5.5866e-07 - accuracy: 1.0000 - val_loss: 3.4233 - val_accuracy: 0.7190
# Epoch 99/100
# 60/60 [==============================] - 5s 83ms/step - loss: 5.3795e-07 - accuracy: 1.0000 - val_loss: 3.4291 - val_accuracy: 0.7170
# Epoch 100/100
# 60/60 [==============================] - 5s 86ms/step - loss: 5.1472e-07 - accuracy: 1.0000 - val_loss: 3.4340 - val_accuracy: 0.7190

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Basic CNN Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,101))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 151, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 101, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
model.save('1-basic-cnn.h5')

# %%
# !pwd
# Out:
# /content

# %%
# !cp ./1-basic-cnn.h5/content/drive/MyDrive/날씨-따릉이*
# Out:
# cp: missing destination file operand after './1-basic-cnn.h5/content/drive/MyDrive/날씨-따릉이*'
# Try 'cp --help' for more information.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
